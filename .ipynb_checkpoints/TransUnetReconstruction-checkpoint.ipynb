# %% [markdown]
# # TransUnet Model

# %% [markdown]
# ## Module imoprts

# %%
# import numpy as np
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)
import os
import cv2
import import_ipynb
import Utils
from tensorflow.keras import backend as K
# from skimage import util

# %%
from tensorflow.keras import layers,losses,Sequential,metrics
from tensorflow.keras.layers import *
from tensorflow.keras.losses import *
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from CBAM import ConvolutionBlockAttentionModule

# %% [markdown]
# ## Reading the data

# %%
image_data = Utils.read_data("Berea_2d25um_binary.raw")
image_data.shape
# Out:
# (1000, 1000, 1000)

# %% [markdown]
# ## Voxel Extraction

# %%
voxels = Utils.extract_subvolumes(image_data)
voxels.shape
# Out:
# (64, 250, 256, 256, 1)

# %%
del image_data

# %% [markdown]
# ## Model Config

# %%
CONFIGURATION = {
    "BATCH_SIZE": 32,
    "IM_SIZE": 256,
    "LEARNING_RATE": 1e-3,
    "N_EPOCHS": 20,
    "DROPOUT_RATE": 0.0,
    "REGULARIZATION_RATE": 0.0,
    "N_FILTERS": 6,
    "KERNEL_SIZE": 3,
    "N_STRIDES": 1,
    "POOL_SIZE": 2,
    "N_DENSE_1": 1024,
    "N_DENSE_2": 128,
    "NUM_CLASSES": 3,
    "PATCH_SIZE": 16,
    "PROJ_DIM": 768,
}

# %% [markdown]
# ## Loss functions

# %%
def calculate_kl_loss(model):
    def _calculate_kl_loss(*args):
        kld = tf.keras.losses.KLDivergence()
        kl_loss = kld(model.inferenceDistribution,model.learnedDistribution)
        return kl_loss
    return _calculate_kl_loss

def _calculate_reconstruction_loss(y_target, y_predicted):
    mse = losses.MeanSquaredError()
    reconstruction_loss = mse( y_target, y_predicted )
    return reconstruction_loss


def _calculate_porosity_loss(y_target,y_predicted):
    por1 = tf.reduce_mean(y_target,axis=(1, 2))
    por2 = tf.reduce_mean(y_predicted,axis=(1, 2))
    mae = losses.MeanSquaredError()
    return mae(por1,por2)

# %% [markdown]
# ## Model Class

# %% [markdown]
# ### Transformer Architecture

# %% [markdown]
# #### Patch Encoder

# %%
class PatchEncoder(Layer):
  def __init__(self, N_PATCHES, HIDDEN_SIZE):
    super(PatchEncoder, self).__init__(name = 'patch_encoder')

    self.linear_projection = Dense(HIDDEN_SIZE)
    self.positional_embedding = Embedding(N_PATCHES, HIDDEN_SIZE )
    self.N_PATCHES = N_PATCHES

  def call(self, x):
    patches = tf.image.extract_patches(
        images=x,
        sizes=[1, CONFIGURATION["PATCH_SIZE"], CONFIGURATION["PATCH_SIZE"], 1],
        strides=[1, CONFIGURATION["PATCH_SIZE"], CONFIGURATION["PATCH_SIZE"], 1],
        rates=[1, 1, 1, 1],
        padding='VALID')
    
    patches = tf.reshape(patches, (tf.shape(patches)[0], 256, patches.shape[-1]))
    
    embedding_input = tf.range(start = 0, limit = self.N_PATCHES, delta = 1 )
    output = self.linear_projection(patches) + self.positional_embedding(embedding_input)
    
    return output

# %% [markdown]
# #### Transformer Encoder

# %%
class TransformerEncoder(Layer):
  def __init__(self, N_HEADS, HIDDEN_SIZE):
    super(TransformerEncoder, self).__init__(name = 'transformer_encoder')

    self.layer_norm_1 = LayerNormalization()
    self.layer_norm_2 = LayerNormalization()
    
    self.multi_head_att = MultiHeadAttention(N_HEADS, HIDDEN_SIZE )
    
    self.dense_1 = Dense(HIDDEN_SIZE, activation = tf.nn.gelu)
    self.dense_2 = Dense(HIDDEN_SIZE, activation = tf.nn.gelu)
    
  def call(self, input):
    x_1 = self.layer_norm_1(input)
    x_1 = self.multi_head_att(x_1, x_1)

    x_1 = Add()([x_1, input])

    x_2 = self.layer_norm_2(x_1)
    x_2 = self.dense_1(x_2)
    output = self.dense_2(x_2)
    output = Add()([output, x_1])

    return output

# %% [markdown]
# #### Vision Transformer

# %%
class ViT(Model):
  def __init__(self, N_HEADS, HIDDEN_SIZE, N_PATCHES, N_LAYERS, N_DENSE_UNITS):
    super(ViT, self).__init__(name = 'vision_transformer')
    self.N_LAYERS = N_LAYERS
    self.patch_encoder = PatchEncoder(N_PATCHES, HIDDEN_SIZE)
    self.trans_encoders = [TransformerEncoder(N_HEADS, HIDDEN_SIZE) for _ in range(N_LAYERS)]
    self.dense_1 = Dense(N_DENSE_UNITS*2, 'gelu',kernel_initializer='glorot_uniform')
    self.mu = Dense(N_DENSE_UNITS, activation = 'sigmoid',kernel_initializer='glorot_uniform')
    self.sigma = Dense(N_DENSE_UNITS, activation = 'sigmoid',kernel_initializer='glorot_uniform')
  def sample_z(self,args):
      z_mu, z_sigma = args
      eps = K.random_normal(shape=(K.shape(z_mu)[0], K.int_shape(z_mu)[1]))
      return z_mu + K.exp(z_sigma / 2) * eps
  def call(self, inputs, training = True):

    x = self.patch_encoder(inputs)

    for i in range(self.N_LAYERS):
      x = self.trans_encoders[i](x)
    x = Flatten()(x)
    x = self.dense_1(x)
    mu = self.mu(x)
    sigma = self.sigma(x)
    z = Lambda(self.sample_z, output_shape=(64, ), name='z')([mu, sigma])
    return z

# %% [markdown]
# ##### ViT Example

# %%
# vit = ViT(
#     N_HEADS = 4, HIDDEN_SIZE = 256, N_PATCHES = 256,
#     N_LAYERS = 2, N_DENSE_UNITS = 64)
# vit(tf.zeros([256,1,1,1]))

# %%
# vit.summary()

# %%
class Reconstruction():
    """
    Reconstruction represents a Deep Convolutional variational autoencoder architecture
    with mirrored encoder and decoder components.
    """

    def __init__(self,
                 inputShape=(256,256,1),
                 latent_space_dim = 64,
                 reducedDimension = 256,
                 convFilters = [16,32,64,128,256]
                )-> None:
        
        
        
        ##### inputs ######
        self.inputShape = inputShape # [256, 256, 1]
        self.latent_space_dim = latent_space_dim # 64
        self.reducedDimension = reducedDimension #256
        
        ##### Loss weights ######
        self.reconstruction_loss_weight = 1
        self.Kullback_leibler_weight = 0.001
        self.porosity_Loss_weight = 1
        
        self.skipConnections = None

        self.learnedPrior = None
        self.inference = None
        self.Generate = None

        
        
        self.learnedDistribution = None
        self.inferenceDistribution = None
        
        self._build()

    def summary(self):
        self.learnedPrior.summary()
        self.inference.summary()
        self.Generate.summary()
    
    def compile(self, learning_rate=0.0001):
        optimizer = Adam(learning_rate=learning_rate)
        self.Generate.compile(optimizer=optimizer,
                           loss=self._calculate_combined_loss,
                           metrics=[_calculate_reconstruction_loss,
                                    _calculate_porosity_loss,
                                    calculate_kl_loss(self)],
                             experimental_run_tf_function=False)
    
    def train(self, inputs1,inputs2, batch_size, num_epochs):
        return self.Generate.fit(x=[inputs1,inputs2],
                       y=inputs2,
                       batch_size=batch_size,
                       epochs=num_epochs,
                       )
    
#     def save(self, save_folder="."):
#         self._create_folder_if_it_doesnt_exist(save_folder)
#         self._save_parameters(save_folder)
#         self._save_weights(save_folder)

#     def load_weights(self, weights_path):
#         self.model.load_weights(weights_path)


#      @classmethod
#     def load(cls, save_folder="."):
#         parameters_path = os.path.join(save_folder, "parameters.pkl")
#         with open(parameters_path, "rb") as f:
#             parameters = pickle.load(f)
#         autoencoder = Reconstruction(*parameters)
#         weights_path = os.path.join(save_folder, "weights.h5")
#         autoencoder.load_weights(weights_path)
#         return autoencoder

    def _calculate_combined_loss(self, y_target, y_predicted):
        
        
        reconstruction_loss = _calculate_reconstruction_loss(y_target,y_predicted)
        kl_loss = calculate_kl_loss(self)(self.inferenceDistribution, self.learnedDistribution)
        porisity_loss = _calculate_porosity_loss(y_target, y_predicted)
        combined_loss = self.reconstruction_loss_weight * reconstruction_loss\
                                                         + kl_loss * self.Kullback_leibler_weight\
                                                         + porisity_loss * self.porosity_Loss_weight
        return combined_loss
    


    def _build(self):
        self._build_inference()
        self._build_learned_prior()
        self._build_generate()
    
    ######  inference ########
    
    
        
    def _build_inference(self):
        self.inference = ViT(
    N_HEADS = 4, HIDDEN_SIZE = 256, N_PATCHES = 256,
    N_LAYERS = 2, N_DENSE_UNITS = 64)
        
        
    ######   learned prior ########
        
    def _build_learned_prior(self):
        
        self.learnedPrior = ViT(
    N_HEADS = 4, HIDDEN_SIZE = 256, N_PATCHES = 256,
    N_LAYERS = 2, N_DENSE_UNITS = 64)
    
    #### generate ######
    
    def _build_generate(self):
        

        
        input_learned = layers.Input(shape=self.inputShape, name="learned_input")
        input_inference = layers.Input(shape=self.inputShape, name="inference_input")
        

        
        self.learnedDistribution = self.learnedPrior(input_learned)
        self.inferenceDistribution = self.inference(input_inference)
        
        
        
        
        conv_1 = layers.Conv2D(16, (3,3) ,input_shape = self.inputShape , activation='relu',
                               padding='same' , name="first_encoder_conv")(input_learned)
        bn1 = layers.BatchNormalization()(conv_1)
        mp1 = layers.MaxPooling2D((2,2), padding='same')(bn1)
        
        
        conv_2 = layers.Conv2D(32, (3,3) , activation='relu'
                               , padding='same' , name="second_encoder_conv" )(mp1)
        bn2 = layers.BatchNormalization()(conv_2)
        mp2 = layers.MaxPooling2D((2,2), padding='same')(bn2)
        
        
        conv_3 = layers.Conv2D(64, (3,3) , activation='relu'
                               , padding='same', name="third_encoder_conv")(mp2)
        bn3 = layers.BatchNormalization()(conv_3)
        mp3 = layers.MaxPooling2D((2,2), padding='same')(bn3)
        
        
        
        conv_4 = layers.Conv2D(128, (3,3) , activation='relu'
                               , padding='same' , name="fourth_encoder_conv")(mp3)
        bn4 = layers.BatchNormalization()(conv_4)
        mp4 = layers.MaxPooling2D((2,2), padding='same')(bn4)
        
        
        
        conv_5 = layers.Conv2D(256, (3,3), activation='relu'
                               , padding='same' , name="fifth_encoder_conv")(mp4)
        bn5 = layers.BatchNormalization()(conv_5)
        mp5 = layers.MaxPooling2D((2,2), padding='same')(bn5)
        
        flattened = layers.Flatten()(mp5)
        
        latentDense = layers.Dense(self.reducedDimension,name ="latent_dense")(flattened)
        conv_out = layers.BatchNormalization()(latentDense)
        self.skipConnections = [bn5,bn4,bn3,bn2,bn1]
        
        conv_out = layers.Reshape(( 1 ,self.reducedDimension ))(conv_out)
        self.learnedDistribution = layers.Reshape(( 1 ,self.latent_space_dim ))(self.learnedDistribution)
        
        
        concated_input = layers.Concatenate(axis=-1)([conv_out,self.learnedDistribution])
        
        reshaped = layers.Reshape((1, self.reducedDimension + self.latent_space_dim))(concated_input)
        
        generated = layers.LSTM(self.reducedDimension, return_sequences=True,name="generate_LSTM")(reshaped)
        
        upDense = layers.Dense(8*8*256,name="up_dense")(generated)
        batchNorm_7 = layers.BatchNormalization()(upDense)
        
        reshapedUp = layers.Reshape((8, 8, 256))(batchNorm_7)
        
        convT_1 = layers.Conv2DTranspose(256, (3,3), strides=2, activation='relu'
                                         , padding='same',name="first_decoder_conv")(reshapedUp)
        batchNorm_8 = layers.BatchNormalization()(convT_1)
        batchNorm_8 = layers.Add()([batchNorm_8,self.skipConnections[0]])
        
        cbam_1 = ConvolutionBlockAttentionModule()(batchNorm_8)
        convT_2 = layers.Conv2DTranspose(128, (3,3), strides=2, activation='relu'
                                         , padding='same',name="second_decoder_conv")(cbam_1)
        batchNorm_9 = layers.BatchNormalization()(convT_2)
        batchNorm_9 = layers.Add()([batchNorm_9, self.skipConnections[1]])
        
        
        cbam_2 = ConvolutionBlockAttentionModule()(batchNorm_9)
        convT_3 = layers.Conv2DTranspose(64, (3,3), strides=2, activation='relu'
                                         , padding='same',name="third_decoder_conv")(cbam_2)
        batchNorm_10 = layers.BatchNormalization()(convT_3)
        batchNorm_10 = layers.Add()([batchNorm_10, self.skipConnections[2]])
        
        
        
        cbam_3 = ConvolutionBlockAttentionModule()(batchNorm_10)
        convT_4 = layers.Conv2DTranspose(32, (3,3), strides=2, activation='relu'
                                         , padding='same',name="fourth_decoder_conv")(cbam_3)
        batchNorm_11 = layers.BatchNormalization()(convT_4)
        batchNorm_11 = layers.Add()([batchNorm_11, self.skipConnections[3]])
        
        
        cbam_4 = ConvolutionBlockAttentionModule()(batchNorm_11)
        convT_5 = layers.Conv2DTranspose(16, (3,3), strides=2, activation='relu'
                                         , padding='same',name="fifth_decoder_conv")(cbam_4)
        batchNorm_12 = layers.BatchNormalization()(convT_5)
        batchNorm_12 = layers.Add()([batchNorm_12, self.skipConnections[4]])
        
        
        
        gen_out = layers.Conv2DTranspose(1, (3,3), activation='sigmoid', padding='same')(batchNorm_12)
        
        self.Generate = Model([input_learned,input_inference], gen_out, name="generate")

# %% [markdown]
# ## TensorFlow gpu setup

# %%
device = tf.config.list_physical_devices("GPU")
print(device)
tf.config.experimental.set_memory_growth(device[0],True)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Model creation

# %%
reconstruction = Reconstruction()
reconstruction.summary()
reconstruction.compile()
batch_size = 10
epochs = 10

# for voxel in X_train:
#     reconstruction.train(voxel, batch_size, epochs)
# Out:
# WARNING:tensorflow:Layer generate_LSTM will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "vision_transformer"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# patch_encoder (PatchEncoder) (None, 256, 256)          131328
# _________________________________________________________________
# transformer_encoder (Transfo (None, 256, 256)          1184512
# _________________________________________________________________
# transformer_encoder (Transfo (None, 256, 256)          1184512
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               8388736
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_15 (Dense)             (None, 64)                8256
# =================================================================
# Total params: 10,905,600
# Trainable params: 10,905,600
# Non-trainable params: 0
# _________________________________________________________________
# Model: "vision_transformer"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# patch_encoder (PatchEncoder) (None, 256, 256)          131328
# _________________________________________________________________
# transformer_encoder (Transfo (None, 256, 256)          1184512
# _________________________________________________________________
# transformer_encoder (Transfo (None, 256, 256)          1184512
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               8388736
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                8256
# =================================================================
# Total params: 10,905,600
# Trainable params: 10,905,600
# Non-trainable params: 0
# _________________________________________________________________
# Model: "generate"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# learned_input (InputLayer)      [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# first_encoder_conv (Conv2D)     (None, 256, 256, 16) 160         learned_input[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 16) 64          first_encoder_conv[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# second_encoder_conv (Conv2D)    (None, 128, 128, 32) 4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 32) 128         second_encoder_conv[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# third_encoder_conv (Conv2D)     (None, 64, 64, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 64)   256         third_encoder_conv[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# fourth_encoder_conv (Conv2D)    (None, 32, 32, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 128)  512         fourth_encoder_conv[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# fifth_encoder_conv (Conv2D)     (None, 16, 16, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 256)  1024        fifth_encoder_conv[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 256)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 16384)        0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# latent_dense (Dense)            (None, 256)          4194560     flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 256)          1024        latent_dense[0][0]
# __________________________________________________________________________________________________
# vision_transformer (ViT)        (None, 64)           10905600    learned_input[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 256)       0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 64)        0           vision_transformer[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1, 320)       0           reshape[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 320)       0           concatenate[0][0]
# __________________________________________________________________________________________________
# generate_LSTM (LSTM)            (None, 1, 256)       590848      reshape_2[0][0]
# __________________________________________________________________________________________________
# up_dense (Dense)                (None, 1, 16384)     4210688     generate_LSTM[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 1, 16384)     65536       up_dense[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 8, 8, 256)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# first_decoder_conv (Conv2DTrans (None, 16, 16, 256)  590080      reshape_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 256)  1024        first_decoder_conv[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 16, 16, 256)  0           batch_normalization_7[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# convolution_block_attention_mod (None, 16, 16, 256)  2137        add_8[0][0]
# __________________________________________________________________________________________________
# second_decoder_conv (Conv2DTran (None, 32, 32, 128)  295040      convolution_block_attention_modul
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 128)  512         second_decoder_conv[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 32, 32, 128)  0           batch_normalization_8[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# convolution_block_attention_mod (None, 32, 32, 128)  1113        add_9[0][0]
# __________________________________________________________________________________________________
# third_decoder_conv (Conv2DTrans (None, 64, 64, 64)   73792       convolution_block_attention_modul
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64, 64, 64)   256         third_decoder_conv[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 64, 64, 64)   0           batch_normalization_9[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# convolution_block_attention_mod (None, 64, 64, 64)   601         add_10[0][0]
# __________________________________________________________________________________________________
# fourth_decoder_conv (Conv2DTran (None, 128, 128, 32) 18464       convolution_block_attention_modul
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 128, 128, 32) 128         fourth_decoder_conv[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 128, 128, 32) 0           batch_normalization_10[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# convolution_block_attention_mod (None, 128, 128, 32) 345         add_11[0][0]
# __________________________________________________________________________________________________
# fifth_decoder_conv (Conv2DTrans (None, 256, 256, 16) 4624        convolution_block_attention_modul
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 256, 256, 16) 64          fifth_decoder_conv[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 256, 256, 16) 0           batch_normalization_11[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# inference_input (InputLayer)    [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 256, 256, 1)  145         add_12[0][0]
# ==================================================================================================
# Total params: 21,350,885
# Trainable params: 21,315,621
# Non-trainable params: 35,264
# __________________________________________________________________________________________________

# %% [markdown]
# ## train and test data extraction

# %%
X_train = voxels[:-6]
X_test = voxels[-6:]

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.19.5

# %%
del voxels

# %% [markdown]
# ## Creating model input

# %%
learnedVoxels = []
inferenceVoxels = []
for voxel in X_train:
    learnedVoxels.append(voxel[:-1])
    inferenceVoxels.append(voxel[1:])

# learnedVoxels = np.array(learnedVoxels)
# inferenceVoxels = np.array(inferenceVoxels)

# %% [markdown]
# ## Training the model

# %%
histories = []
for i in range(len(learnedVoxels)):
    histories.append(reconstruction.train(learnedVoxels[i],inferenceVoxels[i], batch_size, epochs))
# Out:
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 10s 41ms/sample - loss: 0.3804 - _calculate_reconstruction_loss: 0.1742 - _calculate_porosity_loss: 0.0453 - _calculate_kl_loss: 160.5719
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.2711 - _calculate_reconstruction_loss: 0.0981 - _calculate_porosity_loss: 0.0273 - _calculate_kl_loss: 145.5559
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.2280 - _calculate_reconstruction_loss: 0.0706 - _calculate_porosity_loss: 0.0173 - _calculate_kl_loss: 140.0713
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.2051 - _calculate_reconstruction_loss: 0.0568 - _calculate_porosity_loss: 0.0119 - _calculate_kl_loss: 136.3357
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1911 - _calculate_reconstruction_loss: 0.0479 - _calculate_porosity_loss: 0.0087 - _calculate_kl_loss: 134.4217
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1759 - _calculate_reconstruction_loss: 0.0418 - _calculate_porosity_loss: 0.0066 - _calculate_kl_loss: 127.4443
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1695 - _calculate_reconstruction_loss: 0.0380 - _calculate_porosity_loss: 0.0052 - _calculate_kl_loss: 126.2132
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1651 - _calculate_reconstruction_loss: 0.0350 - _calculate_porosity_loss: 0.0042 - _calculate_kl_loss: 125.9415
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1586 - _calculate_reconstruction_loss: 0.0326 - _calculate_porosity_loss: 0.0033 - _calculate_kl_loss: 122.6064
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1587 - _calculate_reconstruction_loss: 0.0312 - _calculate_porosity_loss: 0.0028 - _calculate_kl_loss: 124.7899
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1655 - _calculate_reconstruction_loss: 0.0314 - _calculate_porosity_loss: 0.0033 - _calculate_kl_loss: 130.8285
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1573 - _calculate_reconstruction_loss: 0.0301 - _calculate_porosity_loss: 0.0028 - _calculate_kl_loss: 124.3829
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1597 - _calculate_reconstruction_loss: 0.0290 - _calculate_porosity_loss: 0.0023 - _calculate_kl_loss: 128.3052
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1577 - _calculate_reconstruction_loss: 0.0282 - _calculate_porosity_loss: 0.0020 - _calculate_kl_loss: 127.5204
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1506 - _calculate_reconstruction_loss: 0.0273 - _calculate_porosity_loss: 0.0018 - _calculate_kl_loss: 121.4658
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1573 - _calculate_reconstruction_loss: 0.0264 - _calculate_porosity_loss: 0.0017 - _calculate_kl_loss: 129.2726
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1544 - _calculate_reconstruction_loss: 0.0255 - _calculate_porosity_loss: 0.0015 - _calculate_kl_loss: 127.4388
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1499 - _calculate_reconstruction_loss: 0.0246 - _calculate_porosity_loss: 0.0014 - _calculate_kl_loss: 123.9683
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1506 - _calculate_reconstruction_loss: 0.0237 - _calculate_porosity_loss: 0.0013 - _calculate_kl_loss: 125.5575
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1455 - _calculate_reconstruction_loss: 0.0228 - _calculate_porosity_loss: 0.0012 - _calculate_kl_loss: 121.4333
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1505 - _calculate_reconstruction_loss: 0.0266 - _calculate_porosity_loss: 0.0017 - _calculate_kl_loss: 122.1994
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1477 - _calculate_reconstruction_loss: 0.0243 - _calculate_porosity_loss: 0.0014 - _calculate_kl_loss: 121.8798
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1471 - _calculate_reconstruction_loss: 0.0230 - _calculate_porosity_loss: 0.0013 - _calculate_kl_loss: 122.7174
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1478 - _calculate_reconstruction_loss: 0.0219 - _calculate_porosity_loss: 0.0012 - _calculate_kl_loss: 124.5858
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1480 - _calculate_reconstruction_loss: 0.0209 - _calculate_porosity_loss: 0.0012 - _calculate_kl_loss: 125.8999
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1481 - _calculate_reconstruction_loss: 0.0199 - _calculate_porosity_loss: 0.0011 - _calculate_kl_loss: 127.1479
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1469 - _calculate_reconstruction_loss: 0.0190 - _calculate_porosity_loss: 9.9421e-04 - _calculate_kl_loss: 126.7651
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1420 - _calculate_reconstruction_loss: 0.0181 - _calculate_porosity_loss: 9.1985e-04 - _calculate_kl_loss: 122.9809
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1424 - _calculate_reconstruction_loss: 0.0173 - _calculate_porosity_loss: 8.6349e-04 - _calculate_kl_loss: 124.3796
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1407 - _calculate_reconstruction_loss: 0.0167 - _calculate_porosity_loss: 7.8542e-04 - _calculate_kl_loss: 123.2353
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1446 - _calculate_reconstruction_loss: 0.0256 - _calculate_porosity_loss: 4.0930e-04 - _calculate_kl_loss: 118.5613
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1441 - _calculate_reconstruction_loss: 0.0221 - _calculate_porosity_loss: 3.9430e-04 - _calculate_kl_loss: 121.6283
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1397 - _calculate_reconstruction_loss: 0.0203 - _calculate_porosity_loss: 4.0930e-04 - _calculate_kl_loss: 119.0260
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1463 - _calculate_reconstruction_loss: 0.0190 - _calculate_porosity_loss: 4.0277e-04 - _calculate_kl_loss: 126.9310
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1487 - _calculate_reconstruction_loss: 0.0181 - _calculate_porosity_loss: 4.0073e-04 - _calculate_kl_loss: 130.2542
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1415 - _calculate_reconstruction_loss: 0.0171 - _calculate_porosity_loss: 3.8254e-04 - _calculate_kl_loss: 123.9895
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1419 - _calculate_reconstruction_loss: 0.0164 - _calculate_porosity_loss: 3.7692e-04 - _calculate_kl_loss: 125.0956
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1401 - _calculate_reconstruction_loss: 0.0158 - _calculate_porosity_loss: 3.5678e-04 - _calculate_kl_loss: 124.0092
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1429 - _calculate_reconstruction_loss: 0.0151 - _calculate_porosity_loss: 3.4471e-04 - _calculate_kl_loss: 127.4838
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1380 - _calculate_reconstruction_loss: 0.0146 - _calculate_porosity_loss: 3.3625e-04 - _calculate_kl_loss: 123.1285
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1544 - _calculate_reconstruction_loss: 0.0274 - _calculate_porosity_loss: 5.5450e-05 - _calculate_kl_loss: 126.9698
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1507 - _calculate_reconstruction_loss: 0.0227 - _calculate_porosity_loss: 5.2793e-05 - _calculate_kl_loss: 127.9773
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1473 - _calculate_reconstruction_loss: 0.0202 - _calculate_porosity_loss: 6.7353e-05 - _calculate_kl_loss: 127.0703
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1452 - _calculate_reconstruction_loss: 0.0185 - _calculate_porosity_loss: 6.8235e-05 - _calculate_kl_loss: 126.5336
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1454 - _calculate_reconstruction_loss: 0.0172 - _calculate_porosity_loss: 7.3505e-05 - _calculate_kl_loss: 128.1770
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1435 - _calculate_reconstruction_loss: 0.0164 - _calculate_porosity_loss: 6.4560e-05 - _calculate_kl_loss: 127.0103
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1435 - _calculate_reconstruction_loss: 0.0155 - _calculate_porosity_loss: 8.1160e-05 - _calculate_kl_loss: 127.9189
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1391 - _calculate_reconstruction_loss: 0.0148 - _calculate_porosity_loss: 7.6961e-05 - _calculate_kl_loss: 124.2210
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1420 - _calculate_reconstruction_loss: 0.0143 - _calculate_porosity_loss: 7.8990e-05 - _calculate_kl_loss: 127.5156
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1427 - _calculate_reconstruction_loss: 0.0137 - _calculate_porosity_loss: 7.2461e-05 - _calculate_kl_loss: 128.9666
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1585 - _calculate_reconstruction_loss: 0.0276 - _calculate_porosity_loss: 8.8672e-05 - _calculate_kl_loss: 130.9163
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1499 - _calculate_reconstruction_loss: 0.0228 - _calculate_porosity_loss: 8.4584e-05 - _calculate_kl_loss: 127.0632
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1456 - _calculate_reconstruction_loss: 0.0201 - _calculate_porosity_loss: 1.0011e-04 - _calculate_kl_loss: 125.3252
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1423 - _calculate_reconstruction_loss: 0.0184 - _calculate_porosity_loss: 1.0414e-04 - _calculate_kl_loss: 123.8760
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1440 - _calculate_reconstruction_loss: 0.0170 - _calculate_porosity_loss: 1.0141e-04 - _calculate_kl_loss: 126.9441
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1409 - _calculate_reconstruction_loss: 0.0161 - _calculate_porosity_loss: 1.0704e-04 - _calculate_kl_loss: 124.7182
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1444 - _calculate_reconstruction_loss: 0.0154 - _calculate_porosity_loss: 1.1110e-04 - _calculate_kl_loss: 128.9050
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1373 - _calculate_reconstruction_loss: 0.0148 - _calculate_porosity_loss: 1.0488e-04 - _calculate_kl_loss: 122.3548
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1413 - _calculate_reconstruction_loss: 0.0143 - _calculate_porosity_loss: 1.0202e-04 - _calculate_kl_loss: 126.9962
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1419 - _calculate_reconstruction_loss: 0.0138 - _calculate_porosity_loss: 1.0322e-04 - _calculate_kl_loss: 128.0480
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1520 - _calculate_reconstruction_loss: 0.0288 - _calculate_porosity_loss: 3.9868e-05 - _calculate_kl_loss: 123.2524
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1515 - _calculate_reconstruction_loss: 0.0237 - _calculate_porosity_loss: 3.8778e-05 - _calculate_kl_loss: 127.8575
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1466 - _calculate_reconstruction_loss: 0.0210 - _calculate_porosity_loss: 4.6868e-05 - _calculate_kl_loss: 125.5143
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1466 - _calculate_reconstruction_loss: 0.0192 - _calculate_porosity_loss: 6.1599e-05 - _calculate_kl_loss: 127.2666
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1492 - _calculate_reconstruction_loss: 0.0177 - _calculate_porosity_loss: 5.7484e-05 - _calculate_kl_loss: 131.4028
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1446 - _calculate_reconstruction_loss: 0.0168 - _calculate_porosity_loss: 5.6393e-05 - _calculate_kl_loss: 127.7859
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1431 - _calculate_reconstruction_loss: 0.0161 - _calculate_porosity_loss: 6.0267e-05 - _calculate_kl_loss: 126.9435
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1428 - _calculate_reconstruction_loss: 0.0154 - _calculate_porosity_loss: 5.4524e-05 - _calculate_kl_loss: 127.3637
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1384 - _calculate_reconstruction_loss: 0.0147 - _calculate_porosity_loss: 5.6442e-05 - _calculate_kl_loss: 123.5634
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1382 - _calculate_reconstruction_loss: 0.0143 - _calculate_porosity_loss: 6.0814e-05 - _calculate_kl_loss: 123.7916
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1561 - _calculate_reconstruction_loss: 0.0288 - _calculate_porosity_loss: 3.8041e-05 - _calculate_kl_loss: 127.2642
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1557 - _calculate_reconstruction_loss: 0.0236 - _calculate_porosity_loss: 4.4957e-05 - _calculate_kl_loss: 132.0251
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1507 - _calculate_reconstruction_loss: 0.0210 - _calculate_porosity_loss: 5.3197e-05 - _calculate_kl_loss: 129.6423
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1449 - _calculate_reconstruction_loss: 0.0193 - _calculate_porosity_loss: 5.4140e-05 - _calculate_kl_loss: 125.5684
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1449 - _calculate_reconstruction_loss: 0.0179 - _calculate_porosity_loss: 5.4728e-05 - _calculate_kl_loss: 126.8928
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1421 - _calculate_reconstruction_loss: 0.0171 - _calculate_porosity_loss: 5.9160e-05 - _calculate_kl_loss: 124.9381
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1424 - _calculate_reconstruction_loss: 0.0162 - _calculate_porosity_loss: 5.2661e-05 - _calculate_kl_loss: 126.1882
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1393 - _calculate_reconstruction_loss: 0.0155 - _calculate_porosity_loss: 5.7169e-05 - _calculate_kl_loss: 123.7623
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1416 - _calculate_reconstruction_loss: 0.0149 - _calculate_porosity_loss: 5.1549e-05 - _calculate_kl_loss: 126.6514
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1427 - _calculate_reconstruction_loss: 0.0144 - _calculate_porosity_loss: 5.4522e-05 - _calculate_kl_loss: 128.3421
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1542 - _calculate_reconstruction_loss: 0.0267 - _calculate_porosity_loss: 4.2797e-05 - _calculate_kl_loss: 127.5114
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1479 - _calculate_reconstruction_loss: 0.0215 - _calculate_porosity_loss: 3.4941e-05 - _calculate_kl_loss: 126.4131
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1446 - _calculate_reconstruction_loss: 0.0188 - _calculate_porosity_loss: 4.2653e-05 - _calculate_kl_loss: 125.6472
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1463 - _calculate_reconstruction_loss: 0.0170 - _calculate_porosity_loss: 3.9599e-05 - _calculate_kl_loss: 129.2838
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1440 - _calculate_reconstruction_loss: 0.0159 - _calculate_porosity_loss: 5.2342e-05 - _calculate_kl_loss: 128.1000
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1453 - _calculate_reconstruction_loss: 0.0150 - _calculate_porosity_loss: 4.8520e-05 - _calculate_kl_loss: 130.3018
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1407 - _calculate_reconstruction_loss: 0.0143 - _calculate_porosity_loss: 4.6522e-05 - _calculate_kl_loss: 126.2908
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1447 - _calculate_reconstruction_loss: 0.0137 - _calculate_porosity_loss: 4.2189e-05 - _calculate_kl_loss: 131.0121
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1416 - _calculate_reconstruction_loss: 0.0132 - _calculate_porosity_loss: 5.1888e-05 - _calculate_kl_loss: 128.2748
# Epoch 10/10
# 249/249 [==============================] - 8s 34ms/sample - loss: 0.1411 - _calculate_reconstruction_loss: 0.0128 - _calculate_porosity_loss: 3.5981e-05 - _calculate_kl_loss: 128.2281
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1521 - _calculate_reconstruction_loss: 0.0270 - _calculate_porosity_loss: 6.7693e-05 - _calculate_kl_loss: 125.0155
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1486 - _calculate_reconstruction_loss: 0.0221 - _calculate_porosity_loss: 6.8324e-05 - _calculate_kl_loss: 126.4450
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1459 - _calculate_reconstruction_loss: 0.0194 - _calculate_porosity_loss: 7.8712e-05 - _calculate_kl_loss: 126.5151
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1415 - _calculate_reconstruction_loss: 0.0177 - _calculate_porosity_loss: 8.3516e-05 - _calculate_kl_loss: 123.6429
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1429 - _calculate_reconstruction_loss: 0.0166 - _calculate_porosity_loss: 7.4486e-05 - _calculate_kl_loss: 126.2726
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1438 - _calculate_reconstruction_loss: 0.0157 - _calculate_porosity_loss: 7.7048e-05 - _calculate_kl_loss: 128.0418
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1419 - _calculate_reconstruction_loss: 0.0147 - _calculate_porosity_loss: 7.7337e-05 - _calculate_kl_loss: 127.1783
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1391 - _calculate_reconstruction_loss: 0.0142 - _calculate_porosity_loss: 7.0340e-05 - _calculate_kl_loss: 124.8446
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1385 - _calculate_reconstruction_loss: 0.0138 - _calculate_porosity_loss: 6.6969e-05 - _calculate_kl_loss: 124.6665
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1379 - _calculate_reconstruction_loss: 0.0133 - _calculate_porosity_loss: 6.9067e-05 - _calculate_kl_loss: 124.5487
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1514 - _calculate_reconstruction_loss: 0.0259 - _calculate_porosity_loss: 3.3431e-05 - _calculate_kl_loss: 125.4091
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1504 - _calculate_reconstruction_loss: 0.0211 - _calculate_porosity_loss: 4.3805e-05 - _calculate_kl_loss: 129.2741
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1468 - _calculate_reconstruction_loss: 0.0187 - _calculate_porosity_loss: 5.1286e-05 - _calculate_kl_loss: 127.9683
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1481 - _calculate_reconstruction_loss: 0.0172 - _calculate_porosity_loss: 5.6177e-05 - _calculate_kl_loss: 130.8111
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1451 - _calculate_reconstruction_loss: 0.0161 - _calculate_porosity_loss: 5.3366e-05 - _calculate_kl_loss: 128.9211
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1405 - _calculate_reconstruction_loss: 0.0153 - _calculate_porosity_loss: 5.4031e-05 - _calculate_kl_loss: 125.1647
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1397 - _calculate_reconstruction_loss: 0.0147 - _calculate_porosity_loss: 5.2209e-05 - _calculate_kl_loss: 124.9519
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1461 - _calculate_reconstruction_loss: 0.0141 - _calculate_porosity_loss: 5.3152e-05 - _calculate_kl_loss: 132.0591
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1402 - _calculate_reconstruction_loss: 0.0136 - _calculate_porosity_loss: 5.0134e-05 - _calculate_kl_loss: 126.4257
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1417 - _calculate_reconstruction_loss: 0.0132 - _calculate_porosity_loss: 5.2374e-05 - _calculate_kl_loss: 128.4551
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1559 - _calculate_reconstruction_loss: 0.0291 - _calculate_porosity_loss: 5.6063e-05 - _calculate_kl_loss: 126.7885
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1504 - _calculate_reconstruction_loss: 0.0238 - _calculate_porosity_loss: 3.6269e-05 - _calculate_kl_loss: 126.5492
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1470 - _calculate_reconstruction_loss: 0.0212 - _calculate_porosity_loss: 5.7316e-05 - _calculate_kl_loss: 125.6950
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1466 - _calculate_reconstruction_loss: 0.0196 - _calculate_porosity_loss: 4.8604e-05 - _calculate_kl_loss: 126.9855
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1438 - _calculate_reconstruction_loss: 0.0181 - _calculate_porosity_loss: 4.2528e-05 - _calculate_kl_loss: 125.6846
# Epoch 6/10
# 249/249 [==============================] - 8s 34ms/sample - loss: 0.1472 - _calculate_reconstruction_loss: 0.0171 - _calculate_porosity_loss: 3.5843e-05 - _calculate_kl_loss: 130.1103
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1456 - _calculate_reconstruction_loss: 0.0165 - _calculate_porosity_loss: 3.8039e-05 - _calculate_kl_loss: 129.0852
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1414 - _calculate_reconstruction_loss: 0.0158 - _calculate_porosity_loss: 3.3174e-05 - _calculate_kl_loss: 125.5843
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1424 - _calculate_reconstruction_loss: 0.0152 - _calculate_porosity_loss: 3.4710e-05 - _calculate_kl_loss: 127.1250
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1403 - _calculate_reconstruction_loss: 0.0146 - _calculate_porosity_loss: 3.4076e-05 - _calculate_kl_loss: 125.6465
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1513 - _calculate_reconstruction_loss: 0.0254 - _calculate_porosity_loss: 6.2508e-05 - _calculate_kl_loss: 125.8635
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1494 - _calculate_reconstruction_loss: 0.0204 - _calculate_porosity_loss: 6.6005e-05 - _calculate_kl_loss: 128.9334
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1434 - _calculate_reconstruction_loss: 0.0180 - _calculate_porosity_loss: 7.7294e-05 - _calculate_kl_loss: 125.4325
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1444 - _calculate_reconstruction_loss: 0.0164 - _calculate_porosity_loss: 7.0042e-05 - _calculate_kl_loss: 127.9515
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1405 - _calculate_reconstruction_loss: 0.0154 - _calculate_porosity_loss: 7.1786e-05 - _calculate_kl_loss: 125.0613
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1422 - _calculate_reconstruction_loss: 0.0146 - _calculate_porosity_loss: 6.2680e-05 - _calculate_kl_loss: 127.5359
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1434 - _calculate_reconstruction_loss: 0.0140 - _calculate_porosity_loss: 5.9532e-05 - _calculate_kl_loss: 129.3877
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1401 - _calculate_reconstruction_loss: 0.0134 - _calculate_porosity_loss: 6.4111e-05 - _calculate_kl_loss: 126.5345
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1414 - _calculate_reconstruction_loss: 0.0129 - _calculate_porosity_loss: 5.9945e-05 - _calculate_kl_loss: 128.4326
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1371 - _calculate_reconstruction_loss: 0.0126 - _calculate_porosity_loss: 6.6331e-05 - _calculate_kl_loss: 124.4166
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1546 - _calculate_reconstruction_loss: 0.0272 - _calculate_porosity_loss: 3.3587e-05 - _calculate_kl_loss: 127.3119
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1472 - _calculate_reconstruction_loss: 0.0221 - _calculate_porosity_loss: 4.5444e-05 - _calculate_kl_loss: 125.0498
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1482 - _calculate_reconstruction_loss: 0.0194 - _calculate_porosity_loss: 4.4449e-05 - _calculate_kl_loss: 128.8212
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1429 - _calculate_reconstruction_loss: 0.0178 - _calculate_porosity_loss: 5.0665e-05 - _calculate_kl_loss: 125.1291
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1463 - _calculate_reconstruction_loss: 0.0166 - _calculate_porosity_loss: 5.2550e-05 - _calculate_kl_loss: 129.7286
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1417 - _calculate_reconstruction_loss: 0.0157 - _calculate_porosity_loss: 4.7920e-05 - _calculate_kl_loss: 126.0015
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1431 - _calculate_reconstruction_loss: 0.0150 - _calculate_porosity_loss: 4.7216e-05 - _calculate_kl_loss: 128.0857
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1426 - _calculate_reconstruction_loss: 0.0145 - _calculate_porosity_loss: 4.1829e-05 - _calculate_kl_loss: 128.0346
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1425 - _calculate_reconstruction_loss: 0.0140 - _calculate_porosity_loss: 4.4096e-05 - _calculate_kl_loss: 128.5248
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1399 - _calculate_reconstruction_loss: 0.0135 - _calculate_porosity_loss: 3.9415e-05 - _calculate_kl_loss: 126.4174
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1545 - _calculate_reconstruction_loss: 0.0290 - _calculate_porosity_loss: 2.5349e-05 - _calculate_kl_loss: 125.5039
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1511 - _calculate_reconstruction_loss: 0.0237 - _calculate_porosity_loss: 3.0640e-05 - _calculate_kl_loss: 127.3468
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1486 - _calculate_reconstruction_loss: 0.0209 - _calculate_porosity_loss: 3.1373e-05 - _calculate_kl_loss: 127.6798
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1453 - _calculate_reconstruction_loss: 0.0191 - _calculate_porosity_loss: 3.0681e-05 - _calculate_kl_loss: 126.0919
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1463 - _calculate_reconstruction_loss: 0.0179 - _calculate_porosity_loss: 3.2301e-05 - _calculate_kl_loss: 128.3229
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1446 - _calculate_reconstruction_loss: 0.0169 - _calculate_porosity_loss: 2.8725e-05 - _calculate_kl_loss: 127.6719
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1415 - _calculate_reconstruction_loss: 0.0162 - _calculate_porosity_loss: 3.1283e-05 - _calculate_kl_loss: 125.2110
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1428 - _calculate_reconstruction_loss: 0.0155 - _calculate_porosity_loss: 2.9776e-05 - _calculate_kl_loss: 127.2846
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1412 - _calculate_reconstruction_loss: 0.0152 - _calculate_porosity_loss: 3.2370e-05 - _calculate_kl_loss: 125.9542
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1425 - _calculate_reconstruction_loss: 0.0147 - _calculate_porosity_loss: 2.5608e-05 - _calculate_kl_loss: 127.7348
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1578 - _calculate_reconstruction_loss: 0.0319 - _calculate_porosity_loss: 2.9889e-05 - _calculate_kl_loss: 125.8610
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1488 - _calculate_reconstruction_loss: 0.0259 - _calculate_porosity_loss: 2.1516e-05 - _calculate_kl_loss: 122.9499
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1505 - _calculate_reconstruction_loss: 0.0228 - _calculate_porosity_loss: 2.2071e-05 - _calculate_kl_loss: 127.6893
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1470 - _calculate_reconstruction_loss: 0.0208 - _calculate_porosity_loss: 1.7080e-05 - _calculate_kl_loss: 126.1429
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1504 - _calculate_reconstruction_loss: 0.0196 - _calculate_porosity_loss: 1.7937e-05 - _calculate_kl_loss: 130.7583
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1450 - _calculate_reconstruction_loss: 0.0185 - _calculate_porosity_loss: 1.5685e-05 - _calculate_kl_loss: 126.4866
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1423 - _calculate_reconstruction_loss: 0.0178 - _calculate_porosity_loss: 1.8608e-05 - _calculate_kl_loss: 124.4915
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1437 - _calculate_reconstruction_loss: 0.0170 - _calculate_porosity_loss: 1.4667e-05 - _calculate_kl_loss: 126.5921
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1446 - _calculate_reconstruction_loss: 0.0164 - _calculate_porosity_loss: 1.3733e-05 - _calculate_kl_loss: 128.3286
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1427 - _calculate_reconstruction_loss: 0.0160 - _calculate_porosity_loss: 1.4007e-05 - _calculate_kl_loss: 126.6713
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1508 - _calculate_reconstruction_loss: 0.0242 - _calculate_porosity_loss: 1.0285e-04 - _calculate_kl_loss: 126.4847
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1482 - _calculate_reconstruction_loss: 0.0198 - _calculate_porosity_loss: 8.9199e-05 - _calculate_kl_loss: 128.2980
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1464 - _calculate_reconstruction_loss: 0.0173 - _calculate_porosity_loss: 9.7713e-05 - _calculate_kl_loss: 129.0368
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1445 - _calculate_reconstruction_loss: 0.0158 - _calculate_porosity_loss: 9.6728e-05 - _calculate_kl_loss: 128.6323
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1440 - _calculate_reconstruction_loss: 0.0147 - _calculate_porosity_loss: 8.9967e-05 - _calculate_kl_loss: 129.2621
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1424 - _calculate_reconstruction_loss: 0.0139 - _calculate_porosity_loss: 7.2796e-05 - _calculate_kl_loss: 128.4501
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1405 - _calculate_reconstruction_loss: 0.0132 - _calculate_porosity_loss: 6.7979e-05 - _calculate_kl_loss: 127.3157
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1371 - _calculate_reconstruction_loss: 0.0126 - _calculate_porosity_loss: 6.2672e-05 - _calculate_kl_loss: 124.4231
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1365 - _calculate_reconstruction_loss: 0.0121 - _calculate_porosity_loss: 5.6964e-05 - _calculate_kl_loss: 124.3920
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1404 - _calculate_reconstruction_loss: 0.0120 - _calculate_porosity_loss: 5.4074e-05 - _calculate_kl_loss: 128.3586
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1556 - _calculate_reconstruction_loss: 0.0261 - _calculate_porosity_loss: 2.7047e-05 - _calculate_kl_loss: 129.3853
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1462 - _calculate_reconstruction_loss: 0.0208 - _calculate_porosity_loss: 3.8437e-05 - _calculate_kl_loss: 125.3252
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1432 - _calculate_reconstruction_loss: 0.0183 - _calculate_porosity_loss: 4.4593e-05 - _calculate_kl_loss: 124.8889
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1470 - _calculate_reconstruction_loss: 0.0167 - _calculate_porosity_loss: 4.2528e-05 - _calculate_kl_loss: 130.2953
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1433 - _calculate_reconstruction_loss: 0.0157 - _calculate_porosity_loss: 4.1101e-05 - _calculate_kl_loss: 127.5796
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1402 - _calculate_reconstruction_loss: 0.0147 - _calculate_porosity_loss: 3.7233e-05 - _calculate_kl_loss: 125.4728
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1392 - _calculate_reconstruction_loss: 0.0141 - _calculate_porosity_loss: 3.7357e-05 - _calculate_kl_loss: 125.0261
# Epoch 8/10
# 249/249 [==============================] - 9s 35ms/sample - loss: 0.1425 - _calculate_reconstruction_loss: 0.0135 - _calculate_porosity_loss: 3.5586e-05 - _calculate_kl_loss: 128.9522
# Epoch 9/10
# 249/249 [==============================] - 8s 34ms/sample - loss: 0.1414 - _calculate_reconstruction_loss: 0.0131 - _calculate_porosity_loss: 3.1131e-05 - _calculate_kl_loss: 128.1543
# Epoch 10/10
# 249/249 [==============================] - 8s 34ms/sample - loss: 0.1413 - _calculate_reconstruction_loss: 0.0126 - _calculate_porosity_loss: 3.3132e-05 - _calculate_kl_loss: 128.7239
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1537 - _calculate_reconstruction_loss: 0.0244 - _calculate_porosity_loss: 2.0333e-05 - _calculate_kl_loss: 129.3863
# Epoch 2/10
# 249/249 [==============================] - 8s 34ms/sample - loss: 0.1453 - _calculate_reconstruction_loss: 0.0194 - _calculate_porosity_loss: 2.6345e-05 - _calculate_kl_loss: 125.8593
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1472 - _calculate_reconstruction_loss: 0.0171 - _calculate_porosity_loss: 3.1667e-05 - _calculate_kl_loss: 130.1376
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1421 - _calculate_reconstruction_loss: 0.0156 - _calculate_porosity_loss: 3.0522e-05 - _calculate_kl_loss: 126.4721
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1442 - _calculate_reconstruction_loss: 0.0146 - _calculate_porosity_loss: 2.8897e-05 - _calculate_kl_loss: 129.5799
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1427 - _calculate_reconstruction_loss: 0.0139 - _calculate_porosity_loss: 2.8122e-05 - _calculate_kl_loss: 128.7529
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1403 - _calculate_reconstruction_loss: 0.0134 - _calculate_porosity_loss: 3.0075e-05 - _calculate_kl_loss: 126.7440
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1398 - _calculate_reconstruction_loss: 0.0128 - _calculate_porosity_loss: 2.5867e-05 - _calculate_kl_loss: 126.9900
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1381 - _calculate_reconstruction_loss: 0.0123 - _calculate_porosity_loss: 2.4503e-05 - _calculate_kl_loss: 125.7136
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1371 - _calculate_reconstruction_loss: 0.0120 - _calculate_porosity_loss: 2.1748e-05 - _calculate_kl_loss: 125.1684
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1518 - _calculate_reconstruction_loss: 0.0256 - _calculate_porosity_loss: 3.6984e-05 - _calculate_kl_loss: 126.1392
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1481 - _calculate_reconstruction_loss: 0.0208 - _calculate_porosity_loss: 4.4546e-05 - _calculate_kl_loss: 127.2226
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1449 - _calculate_reconstruction_loss: 0.0184 - _calculate_porosity_loss: 4.5599e-05 - _calculate_kl_loss: 126.4467
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1430 - _calculate_reconstruction_loss: 0.0168 - _calculate_porosity_loss: 4.8806e-05 - _calculate_kl_loss: 126.1202
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1428 - _calculate_reconstruction_loss: 0.0157 - _calculate_porosity_loss: 4.1663e-05 - _calculate_kl_loss: 126.9689
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1438 - _calculate_reconstruction_loss: 0.0149 - _calculate_porosity_loss: 3.8388e-05 - _calculate_kl_loss: 128.9059
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1412 - _calculate_reconstruction_loss: 0.0144 - _calculate_porosity_loss: 3.8148e-05 - _calculate_kl_loss: 126.7580
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1431 - _calculate_reconstruction_loss: 0.0137 - _calculate_porosity_loss: 3.4658e-05 - _calculate_kl_loss: 129.2872
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1449 - _calculate_reconstruction_loss: 0.0133 - _calculate_porosity_loss: 3.0792e-05 - _calculate_kl_loss: 131.6757
# Epoch 10/10
# 249/249 [==============================] - 8s 34ms/sample - loss: 0.1356 - _calculate_reconstruction_loss: 0.0128 - _calculate_porosity_loss: 3.3329e-05 - _calculate_kl_loss: 122.7788
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1541 - _calculate_reconstruction_loss: 0.0252 - _calculate_porosity_loss: 2.2630e-05 - _calculate_kl_loss: 128.8021
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1465 - _calculate_reconstruction_loss: 0.0197 - _calculate_porosity_loss: 1.9965e-05 - _calculate_kl_loss: 126.7248
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1442 - _calculate_reconstruction_loss: 0.0171 - _calculate_porosity_loss: 2.1493e-05 - _calculate_kl_loss: 126.9316
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1443 - _calculate_reconstruction_loss: 0.0156 - _calculate_porosity_loss: 2.0405e-05 - _calculate_kl_loss: 128.6829
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1397 - _calculate_reconstruction_loss: 0.0145 - _calculate_porosity_loss: 2.3318e-05 - _calculate_kl_loss: 125.1242
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1415 - _calculate_reconstruction_loss: 0.0137 - _calculate_porosity_loss: 1.8042e-05 - _calculate_kl_loss: 127.6773
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1411 - _calculate_reconstruction_loss: 0.0132 - _calculate_porosity_loss: 2.0127e-05 - _calculate_kl_loss: 127.8121
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1399 - _calculate_reconstruction_loss: 0.0128 - _calculate_porosity_loss: 1.9478e-05 - _calculate_kl_loss: 127.2027
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1391 - _calculate_reconstruction_loss: 0.0124 - _calculate_porosity_loss: 1.7653e-05 - _calculate_kl_loss: 126.6559
# Epoch 10/10
# 249/249 [==============================] - 8s 34ms/sample - loss: 0.1403 - _calculate_reconstruction_loss: 0.0119 - _calculate_porosity_loss: 1.4147e-05 - _calculate_kl_loss: 128.3916
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1519 - _calculate_reconstruction_loss: 0.0257 - _calculate_porosity_loss: 2.0982e-05 - _calculate_kl_loss: 126.2235
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1438 - _calculate_reconstruction_loss: 0.0203 - _calculate_porosity_loss: 1.8763e-05 - _calculate_kl_loss: 123.3383
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1461 - _calculate_reconstruction_loss: 0.0177 - _calculate_porosity_loss: 1.9533e-05 - _calculate_kl_loss: 128.3149
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1453 - _calculate_reconstruction_loss: 0.0162 - _calculate_porosity_loss: 1.8969e-05 - _calculate_kl_loss: 129.1318
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1421 - _calculate_reconstruction_loss: 0.0152 - _calculate_porosity_loss: 1.7962e-05 - _calculate_kl_loss: 127.0290
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1446 - _calculate_reconstruction_loss: 0.0144 - _calculate_porosity_loss: 2.0858e-05 - _calculate_kl_loss: 130.1285
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1381 - _calculate_reconstruction_loss: 0.0137 - _calculate_porosity_loss: 1.6829e-05 - _calculate_kl_loss: 124.2951
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1387 - _calculate_reconstruction_loss: 0.0133 - _calculate_porosity_loss: 1.5584e-05 - _calculate_kl_loss: 125.3723
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1344 - _calculate_reconstruction_loss: 0.0127 - _calculate_porosity_loss: 1.5812e-05 - _calculate_kl_loss: 121.6830
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1438 - _calculate_reconstruction_loss: 0.0124 - _calculate_porosity_loss: 1.6029e-05 - _calculate_kl_loss: 131.4500
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1508 - _calculate_reconstruction_loss: 0.0256 - _calculate_porosity_loss: 1.8418e-05 - _calculate_kl_loss: 125.1322
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1485 - _calculate_reconstruction_loss: 0.0204 - _calculate_porosity_loss: 1.7357e-05 - _calculate_kl_loss: 128.1062
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1423 - _calculate_reconstruction_loss: 0.0178 - _calculate_porosity_loss: 1.6032e-05 - _calculate_kl_loss: 124.4257
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1444 - _calculate_reconstruction_loss: 0.0163 - _calculate_porosity_loss: 1.8551e-05 - _calculate_kl_loss: 128.1277
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1418 - _calculate_reconstruction_loss: 0.0152 - _calculate_porosity_loss: 1.6973e-05 - _calculate_kl_loss: 126.5778
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1437 - _calculate_reconstruction_loss: 0.0144 - _calculate_porosity_loss: 1.5673e-05 - _calculate_kl_loss: 129.2771
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1412 - _calculate_reconstruction_loss: 0.0139 - _calculate_porosity_loss: 1.7710e-05 - _calculate_kl_loss: 127.3260
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1423 - _calculate_reconstruction_loss: 0.0134 - _calculate_porosity_loss: 1.7720e-05 - _calculate_kl_loss: 128.8401
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1410 - _calculate_reconstruction_loss: 0.0128 - _calculate_porosity_loss: 1.2020e-05 - _calculate_kl_loss: 128.1080
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1401 - _calculate_reconstruction_loss: 0.0125 - _calculate_porosity_loss: 1.3074e-05 - _calculate_kl_loss: 127.6048
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1532 - _calculate_reconstruction_loss: 0.0273 - _calculate_porosity_loss: 1.7077e-05 - _calculate_kl_loss: 125.8311
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1493 - _calculate_reconstruction_loss: 0.0221 - _calculate_porosity_loss: 1.6062e-05 - _calculate_kl_loss: 127.2143
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1466 - _calculate_reconstruction_loss: 0.0194 - _calculate_porosity_loss: 1.2160e-05 - _calculate_kl_loss: 127.1142
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1480 - _calculate_reconstruction_loss: 0.0178 - _calculate_porosity_loss: 1.8764e-05 - _calculate_kl_loss: 130.1057
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1461 - _calculate_reconstruction_loss: 0.0167 - _calculate_porosity_loss: 1.2719e-05 - _calculate_kl_loss: 129.4974
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1424 - _calculate_reconstruction_loss: 0.0159 - _calculate_porosity_loss: 1.5204e-05 - _calculate_kl_loss: 126.4700
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1461 - _calculate_reconstruction_loss: 0.0152 - _calculate_porosity_loss: 1.3109e-05 - _calculate_kl_loss: 130.8137
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1408 - _calculate_reconstruction_loss: 0.0146 - _calculate_porosity_loss: 1.2687e-05 - _calculate_kl_loss: 126.1705
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1407 - _calculate_reconstruction_loss: 0.0144 - _calculate_porosity_loss: 1.4932e-05 - _calculate_kl_loss: 126.3406
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1440 - _calculate_reconstruction_loss: 0.0139 - _calculate_porosity_loss: 1.1868e-05 - _calculate_kl_loss: 130.1148
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1517 - _calculate_reconstruction_loss: 0.0253 - _calculate_porosity_loss: 1.7316e-05 - _calculate_kl_loss: 126.3946
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1452 - _calculate_reconstruction_loss: 0.0201 - _calculate_porosity_loss: 1.7247e-05 - _calculate_kl_loss: 125.0758
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1450 - _calculate_reconstruction_loss: 0.0173 - _calculate_porosity_loss: 1.8372e-05 - _calculate_kl_loss: 127.5893
# Epoch 4/10
# ...
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1379 - _calculate_reconstruction_loss: 0.0115 - _calculate_porosity_loss: 1.1245e-05 - _calculate_kl_loss: 126.3919
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1575 - _calculate_reconstruction_loss: 0.0257 - _calculate_porosity_loss: 1.5146e-05 - _calculate_kl_loss: 131.7962
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1486 - _calculate_reconstruction_loss: 0.0203 - _calculate_porosity_loss: 1.3308e-05 - _calculate_kl_loss: 128.3202
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1424 - _calculate_reconstruction_loss: 0.0177 - _calculate_porosity_loss: 1.3277e-05 - _calculate_kl_loss: 124.7631
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1394 - _calculate_reconstruction_loss: 0.0160 - _calculate_porosity_loss: 1.1162e-05 - _calculate_kl_loss: 123.4536
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1398 - _calculate_reconstruction_loss: 0.0152 - _calculate_porosity_loss: 1.3807e-05 - _calculate_kl_loss: 124.5745
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1430 - _calculate_reconstruction_loss: 0.0145 - _calculate_porosity_loss: 9.8954e-06 - _calculate_kl_loss: 128.5435
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1418 - _calculate_reconstruction_loss: 0.0137 - _calculate_porosity_loss: 8.9133e-06 - _calculate_kl_loss: 128.1065
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1381 - _calculate_reconstruction_loss: 0.0133 - _calculate_porosity_loss: 1.0691e-05 - _calculate_kl_loss: 124.7033
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1397 - _calculate_reconstruction_loss: 0.0128 - _calculate_porosity_loss: 6.7259e-06 - _calculate_kl_loss: 127.0001
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1347 - _calculate_reconstruction_loss: 0.0125 - _calculate_porosity_loss: 8.1229e-06 - _calculate_kl_loss: 122.1579
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1505 - _calculate_reconstruction_loss: 0.0254 - _calculate_porosity_loss: 1.7046e-05 - _calculate_kl_loss: 125.1230
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1457 - _calculate_reconstruction_loss: 0.0199 - _calculate_porosity_loss: 9.7832e-06 - _calculate_kl_loss: 125.7968
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1414 - _calculate_reconstruction_loss: 0.0175 - _calculate_porosity_loss: 8.7360e-06 - _calculate_kl_loss: 123.8225
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1441 - _calculate_reconstruction_loss: 0.0160 - _calculate_porosity_loss: 9.5737e-06 - _calculate_kl_loss: 128.1490
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1409 - _calculate_reconstruction_loss: 0.0151 - _calculate_porosity_loss: 7.5978e-06 - _calculate_kl_loss: 125.6484
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1413 - _calculate_reconstruction_loss: 0.0144 - _calculate_porosity_loss: 6.2179e-06 - _calculate_kl_loss: 126.7981
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1383 - _calculate_reconstruction_loss: 0.0139 - _calculate_porosity_loss: 5.9796e-06 - _calculate_kl_loss: 124.4550
# Epoch 8/10
# 249/249 [==============================] - 8s 34ms/sample - loss: 0.1391 - _calculate_reconstruction_loss: 0.0135 - _calculate_porosity_loss: 7.1331e-06 - _calculate_kl_loss: 125.6096
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1371 - _calculate_reconstruction_loss: 0.0131 - _calculate_porosity_loss: 6.8079e-06 - _calculate_kl_loss: 123.9721
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1409 - _calculate_reconstruction_loss: 0.0126 - _calculate_porosity_loss: 6.1909e-06 - _calculate_kl_loss: 128.2341
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1480 - _calculate_reconstruction_loss: 0.0238 - _calculate_porosity_loss: 1.1332e-05 - _calculate_kl_loss: 124.1291
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1427 - _calculate_reconstruction_loss: 0.0188 - _calculate_porosity_loss: 1.1802e-05 - _calculate_kl_loss: 123.8868
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1408 - _calculate_reconstruction_loss: 0.0163 - _calculate_porosity_loss: 1.2957e-05 - _calculate_kl_loss: 124.4402
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1409 - _calculate_reconstruction_loss: 0.0148 - _calculate_porosity_loss: 1.0749e-05 - _calculate_kl_loss: 126.0864
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1380 - _calculate_reconstruction_loss: 0.0138 - _calculate_porosity_loss: 9.0817e-06 - _calculate_kl_loss: 124.1095
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1405 - _calculate_reconstruction_loss: 0.0131 - _calculate_porosity_loss: 7.4272e-06 - _calculate_kl_loss: 127.3853
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1390 - _calculate_reconstruction_loss: 0.0125 - _calculate_porosity_loss: 7.5931e-06 - _calculate_kl_loss: 126.5042
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1373 - _calculate_reconstruction_loss: 0.0121 - _calculate_porosity_loss: 7.1425e-06 - _calculate_kl_loss: 125.1861
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1382 - _calculate_reconstruction_loss: 0.0117 - _calculate_porosity_loss: 6.8535e-06 - _calculate_kl_loss: 126.4360
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1371 - _calculate_reconstruction_loss: 0.0113 - _calculate_porosity_loss: 5.2116e-06 - _calculate_kl_loss: 125.6907
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1495 - _calculate_reconstruction_loss: 0.0250 - _calculate_porosity_loss: 1.7447e-05 - _calculate_kl_loss: 124.4882
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1439 - _calculate_reconstruction_loss: 0.0194 - _calculate_porosity_loss: 1.1631e-05 - _calculate_kl_loss: 124.4857
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1420 - _calculate_reconstruction_loss: 0.0167 - _calculate_porosity_loss: 1.1658e-05 - _calculate_kl_loss: 125.4009
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1453 - _calculate_reconstruction_loss: 0.0155 - _calculate_porosity_loss: 1.1446e-05 - _calculate_kl_loss: 129.7212
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1439 - _calculate_reconstruction_loss: 0.0143 - _calculate_porosity_loss: 8.5780e-06 - _calculate_kl_loss: 129.4753
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1428 - _calculate_reconstruction_loss: 0.0137 - _calculate_porosity_loss: 9.5808e-06 - _calculate_kl_loss: 129.0461
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1426 - _calculate_reconstruction_loss: 0.0131 - _calculate_porosity_loss: 5.9287e-06 - _calculate_kl_loss: 129.5408
# Epoch 8/10
# 249/249 [==============================] - 8s 34ms/sample - loss: 0.1353 - _calculate_reconstruction_loss: 0.0126 - _calculate_porosity_loss: 6.3341e-06 - _calculate_kl_loss: 122.7404
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1367 - _calculate_reconstruction_loss: 0.0124 - _calculate_porosity_loss: 8.0016e-06 - _calculate_kl_loss: 124.3399
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1393 - _calculate_reconstruction_loss: 0.0119 - _calculate_porosity_loss: 5.1277e-06 - _calculate_kl_loss: 127.5117
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1541 - _calculate_reconstruction_loss: 0.0255 - _calculate_porosity_loss: 1.3708e-05 - _calculate_kl_loss: 128.6078
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1453 - _calculate_reconstruction_loss: 0.0201 - _calculate_porosity_loss: 1.0384e-05 - _calculate_kl_loss: 125.1942
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1422 - _calculate_reconstruction_loss: 0.0174 - _calculate_porosity_loss: 1.2291e-05 - _calculate_kl_loss: 124.8939
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1398 - _calculate_reconstruction_loss: 0.0160 - _calculate_porosity_loss: 1.0122e-05 - _calculate_kl_loss: 123.8654
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1406 - _calculate_reconstruction_loss: 0.0149 - _calculate_porosity_loss: 8.1427e-06 - _calculate_kl_loss: 125.7069
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1412 - _calculate_reconstruction_loss: 0.0141 - _calculate_porosity_loss: 8.5009e-06 - _calculate_kl_loss: 127.0800
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1419 - _calculate_reconstruction_loss: 0.0136 - _calculate_porosity_loss: 6.7710e-06 - _calculate_kl_loss: 128.4164
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1390 - _calculate_reconstruction_loss: 0.0131 - _calculate_porosity_loss: 8.3667e-06 - _calculate_kl_loss: 125.9416
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1367 - _calculate_reconstruction_loss: 0.0127 - _calculate_porosity_loss: 5.8424e-06 - _calculate_kl_loss: 123.9754
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1400 - _calculate_reconstruction_loss: 0.0123 - _calculate_porosity_loss: 5.6330e-06 - _calculate_kl_loss: 127.7009
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1525 - _calculate_reconstruction_loss: 0.0273 - _calculate_porosity_loss: 2.0267e-05 - _calculate_kl_loss: 125.2211
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1482 - _calculate_reconstruction_loss: 0.0215 - _calculate_porosity_loss: 1.2978e-05 - _calculate_kl_loss: 126.6749
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1458 - _calculate_reconstruction_loss: 0.0187 - _calculate_porosity_loss: 1.1568e-05 - _calculate_kl_loss: 127.1425
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1419 - _calculate_reconstruction_loss: 0.0172 - _calculate_porosity_loss: 1.1491e-05 - _calculate_kl_loss: 124.6832
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1446 - _calculate_reconstruction_loss: 0.0162 - _calculate_porosity_loss: 8.7815e-06 - _calculate_kl_loss: 128.4032
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1385 - _calculate_reconstruction_loss: 0.0154 - _calculate_porosity_loss: 9.1594e-06 - _calculate_kl_loss: 123.0409
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1413 - _calculate_reconstruction_loss: 0.0148 - _calculate_porosity_loss: 7.0461e-06 - _calculate_kl_loss: 126.4939
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1394 - _calculate_reconstruction_loss: 0.0142 - _calculate_porosity_loss: 8.5988e-06 - _calculate_kl_loss: 125.1294
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1396 - _calculate_reconstruction_loss: 0.0140 - _calculate_porosity_loss: 7.0263e-06 - _calculate_kl_loss: 125.5260
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1441 - _calculate_reconstruction_loss: 0.0134 - _calculate_porosity_loss: 5.9263e-06 - _calculate_kl_loss: 130.6783
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1503 - _calculate_reconstruction_loss: 0.0243 - _calculate_porosity_loss: 1.3687e-05 - _calculate_kl_loss: 125.9299
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1450 - _calculate_reconstruction_loss: 0.0192 - _calculate_porosity_loss: 1.4178e-05 - _calculate_kl_loss: 125.7115
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1434 - _calculate_reconstruction_loss: 0.0165 - _calculate_porosity_loss: 1.2198e-05 - _calculate_kl_loss: 126.8419
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1398 - _calculate_reconstruction_loss: 0.0151 - _calculate_porosity_loss: 1.1385e-05 - _calculate_kl_loss: 124.5997
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1414 - _calculate_reconstruction_loss: 0.0143 - _calculate_porosity_loss: 8.6811e-06 - _calculate_kl_loss: 127.1280
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1380 - _calculate_reconstruction_loss: 0.0135 - _calculate_porosity_loss: 9.0879e-06 - _calculate_kl_loss: 124.4956
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1397 - _calculate_reconstruction_loss: 0.0131 - _calculate_porosity_loss: 9.1708e-06 - _calculate_kl_loss: 126.7321
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1388 - _calculate_reconstruction_loss: 0.0124 - _calculate_porosity_loss: 7.0063e-06 - _calculate_kl_loss: 126.4479
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1364 - _calculate_reconstruction_loss: 0.0120 - _calculate_porosity_loss: 5.3448e-06 - _calculate_kl_loss: 124.3124
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1417 - _calculate_reconstruction_loss: 0.0117 - _calculate_porosity_loss: 7.7383e-06 - _calculate_kl_loss: 130.0160
# Train on 249 samples
# Epoch 1/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1548 - _calculate_reconstruction_loss: 0.0245 - _calculate_porosity_loss: 1.8373e-05 - _calculate_kl_loss: 130.3289
# Epoch 2/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1469 - _calculate_reconstruction_loss: 0.0190 - _calculate_porosity_loss: 1.2462e-05 - _calculate_kl_loss: 127.9048
# Epoch 3/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1432 - _calculate_reconstruction_loss: 0.0164 - _calculate_porosity_loss: 1.1217e-05 - _calculate_kl_loss: 126.7371
# Epoch 4/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1414 - _calculate_reconstruction_loss: 0.0150 - _calculate_porosity_loss: 9.2506e-06 - _calculate_kl_loss: 126.4636
# Epoch 5/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1422 - _calculate_reconstruction_loss: 0.0142 - _calculate_porosity_loss: 1.0606e-05 - _calculate_kl_loss: 128.0682
# Epoch 6/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1367 - _calculate_reconstruction_loss: 0.0134 - _calculate_porosity_loss: 8.9926e-06 - _calculate_kl_loss: 123.2995
# Epoch 7/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1384 - _calculate_reconstruction_loss: 0.0128 - _calculate_porosity_loss: 7.1368e-06 - _calculate_kl_loss: 125.5625
# Epoch 8/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1402 - _calculate_reconstruction_loss: 0.0123 - _calculate_porosity_loss: 7.7587e-06 - _calculate_kl_loss: 127.8758
# Epoch 9/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1417 - _calculate_reconstruction_loss: 0.0120 - _calculate_porosity_loss: 5.9314e-06 - _calculate_kl_loss: 129.6862
# Epoch 10/10
# 249/249 [==============================] - 8s 33ms/sample - loss: 0.1375 - _calculate_reconstruction_loss: 0.0117 - _calculate_porosity_loss: 5.1242e-06 - _calculate_kl_loss: 125.8354

# %% [markdown]
# ## Testing the model

# %%
first  = X_test[0]
Topredict = first[1:]
test = first[:-1]

# %%
predicted = []


# for i in range(10):
predicted = reconstruction.Generate.predict([test,Topredict])
# predicted.append(nextLayer)
# #     inputLayer = nextLayer
# predicted.append()
# Out:
# D:\Anaconda\envs\PFE\lib\site-packages\tensorflow\python\keras\engine\training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '

# %%
len(predicted)
# Out:
# 249

# %%
n = 10

plt.figure(figsize=(20,4))
for i in range(n):
    # original
    ax = plt.subplot(2,n,i+1)
    plt.imshow(Topredict[i])
    plt.title('original')
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # reconstructed
    ax = plt.subplot(2,n,i+1+n)
    plt.imshow(predicted[i])
    plt.title('reconstructed')
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

# %%
testing = []
inputLayer = test[0]
for i in range(10):
    testing.append(reconstruction.Generate.predict([inputLayer.reshape(1,256,256,1),Topredict[i].reshape(1,256,256,1)]))
    inputLayer = testing[-1]

# %%
n = 10

plt.figure(figsize=(20,4))
for i in range(n):
    # original
    ax = plt.subplot(2,n,i+1)
    plt.imshow(Topredict[i])
    plt.title('original')
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # reconstructed
    ax = plt.subplot(2,n,i+1+n)
    plt.imshow(testing[i].reshape(256,256,1))
    plt.title('reconstructed')
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
